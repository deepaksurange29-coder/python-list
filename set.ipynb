# %%
#set methods
s={"Red","blue","pink","green","orange"}

# %%
s
# Out:
# {'Red', 'blue', 'green', 'orange', 'pink'}

# %%
s1={100,200,500,400,600}

# %%
s1
# Out:
# {100, 200, 400, 500, 600}

# %%
s
# Out:
# {'Red', 'blue', 'green', 'orange', 'pink'}

# %%
s.add("yellow")

# %%
s
# Out:
# {'Red', 'blue', 'green', 'orange', 'pink', 'yellow'}

# %%
s1.add(300)

# %%
s1
# Out:
# {100, 200, 300, 400, 500, 600}

# %%
s1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 s1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s1.update(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 s1.update(20)
#
# TypeError: 'int' object is not iterable

# %%
s1.update([201,204])

# %%
s1
# Out:
# {100, 200, 201, 204, 300, 400, 500, 600}

# %%
s.update(["black","white"])

# %%
s
# Out:
# {'Red', 'black', 'blue', 'green', 'orange', 'pink', 'white', 'yellow'}

# %%
s.remove("Red")

# %%
s
# Out:
# {'black', 'blue', 'green', 'orange', 'pink', 'white', 'yellow'}

# %%
s1.remove(200)

# %% [markdown]
# s1

# %%
s.discard("green")

# %%
s
# Out:
# {'black', 'blue', 'orange', 'pink', 'white', 'yellow'}

# %%
s1
# Out:
# {100, 201, 204, 300, 500, 600}

# %%
s1.pop()
# Out:
# 204

# %%
s1
# Out:
# {100, 201, 300, 500, 600}

# %%
s.copy()
# Out:
# {'black', 'blue', 'orange', 'pink', 'white', 'yellow'}

# %%
s.clear()

# %%
#set operation 
s1={10,20,30,40,50}
s2={60,20,30,40,30}

# %%
#union
s1.union (s2)
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
s2.union(s1)
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
s1.intersection(s2)
# Out:
# {20, 30, 40}

# %%
s1.difference(s2)
# Out:
# {10, 50}

# %%
s2.symmteric_difference(s1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 s2.symmteric_difference(s1)
#
# AttributeError: 'set' object has no attribute 'symmteric_difference'

# %%
s2.symmetric_difference(s1)
# Out:
# {10, 50, 60}

# %%
#membership 
s1
# Out:
# {10, 20, 30, 40, 50}

# %%
20 in s1
# Out:
# True

# %%
50
# Out:
# 50

# %%
len(s1)
# Out:
# 5

# %%
len(s2)
# Out:
# 4

# %%
s2
# Out:
# {20, 30, 40, 60}

# %%
20 not in s2
# Out:
# False

# %%
80 not in s2
# Out:
# True
