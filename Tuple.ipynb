# %%
#tuple
#methods
t1=(10,20,30,40,50)

# %%
t1
# Out:
# (10, 20, 30, 40, 50)

# %%
t1.index(10)
# Out:
# 0

# %%
t1.index(50)
# Out:
# 4

# %%
t1.add(60)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 t1.add(60)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
del t1(30)
# Out:
#   Cell In[6], line 1
#     del t1(30)
#         ^
# SyntaxError: cannot delete function call

# %%
t1
# Out:
# (10, 20, 30, 40, 50)

# %%
t1.count(10)
# Out:
# 1

# %%
t1.count(40)
# Out:
# 1

# %%
t2=("red","blue","yellow","black")

# %%
t2
# Out:
# ('red', 'blue', 'yellow', 'black')

# %%
t1
# Out:
# (10, 20, 30, 40, 50)

# %%
#operation
#concatenation
t1=(10,20,30,40)
t2=(40,50,60,10)

# %%
t1 + t2
# Out:
# (10, 20, 30, 40, 40, 50, 60, 10)

# %%
#reptition
t1 * 2
# Out:
# (10, 20, 30, 40, 10, 20, 30, 40)

# %%
t2 * 2
# Out:
# (40, 50, 60, 10, 40, 50, 60, 10)

# %%
#membership
10 in t1
# Out:
# True

# %%
50 in t1
# Out:
# False

# %%
40 not in t1
# Out:
# False

# %%
20 not in t2
# Out:
# True

# %%
#indexing
t1
# Out:
# (10, 20, 30, 40)

# %%
t2
# Out:
# (40, 50, 60, 10)

# %%
t2[2]
# Out:
# 60

# %%
t1[3]
# Out:
# 40

# %%
t1[0]
# Out:
# 10

# %%
#slicing
t1[0:2]
# Out:
# (10, 20)

# %%
t1[-4:-1]
# Out:
# (10, 20, 30)

# %%
t2[0:3:1]
# Out:
# (40, 50, 60)

# %%
t2[-3:-1:1]
# Out:
# (50, 60)

# %%
#common
#built-in
#function
max(t1)
# Out:
# 40

# %%
min(t1)
# Out:
# 10

# %%
max(t2)
# Out:
# 60

# %%
min(t2)
# Out:
# 10

# %%
sum(t1)
# Out:
# 100

# %%
sum(t2)
# Out:
# 160

# %%
type(t1)
# Out:
# tuple

# %%
sorted(t1,reverse=True)
# Out:
# [40, 30, 20, 10]

# %%
sorted(t2,reverse=True)
# Out:
# [60, 50, 40, 10]

# %%
t1=("Apple","Apple","Banana","Mango","Orange","jackfruit")

# %%
t1
# Out:
# ('Apple', 'Apple', 'Banana', 'Mango', 'Orange', 'jackfruit')

# %%
t1.count("Apple")
# Out:
# 2

# %%
t1.count("Banana")
# Out:
# 1

# %%
t1[1]
# Out:
# 'Apple'

# %%
t1[5]
# Out:
# 'jackfruit'

# %%
t1.index("Mango")
# Out:
# 3

# %%
t1=(10,20,30,40,50)
t2=(50,70,80,90,10)

# %%
t1+t2
# Out:
# (10, 20, 30, 40, 50, 50, 70, 80, 90, 10)

# %%
t1[2]
# Out:
# 30

# %%
t2[1]
# Out:
# 70

# %%
t1*2
# Out:
# (10, 20, 30, 40, 50, 10, 20, 30, 40, 50)

# %%
t2*3
# Out:
# (50, 70, 80, 90, 10, 50, 70, 80, 90, 10, 50, 70, 80, 90, 10)

# %%
70 in t1
# Out:
# False

# %%
50 in t1
# Out:
# True

# %%
60 in t2
# Out:
# False

# %%
80 in t1
# Out:
# False

# %%
90 not in t1
# Out:
# True

# %%
10 not in t2
# Out:
# False

# %%
t1
# Out:
# (10, 20, 30, 40, 50)

# %%
t1[1:4]
# Out:
# (20, 30, 40)

# %%
t2
# Out:
# (50, 70, 80, 90, 10)

# %%
t2[-4:-1]
# Out:
# (70, 80, 90)

# %%
t2.index(10)
# Out:
# 4

# %%
t1.index(50)
# Out:
# 4

# %%
t1.index(30)
# Out:
# 2

# %%
t1
# Out:
# (10, 20, 30, 40, 50)

# %%
t2
# Out:
# (50, 70, 80, 90, 10)

# %%
sum(t1)
# Out:
# 150

# %%
sum(t2)
# Out:
# 300

# %%
max(t1)
# Out:
# 50

# %%
min(t2)
# Out:
# 10

# %%
len(t1)
# Out:
# 5

# %%
t1.count(10)
# Out:
# 1

# %%
t1=(10,20,30,40,50)

# %%
t1[1]
# Out:
# 20

# %%
t1[4]
# Out:
# 50

# %%
len(t1)
# Out:
# 5

# %%
25 in t1
# Out:
# False

# %%
t2=(5,2,5,8,5,9)

# %%
t2.count(5)
# Out:
# 3

# %%
t1
# Out:
# (10, 20, 30, 40, 50)

# %%
t1.index(30)
# Out:
# 2

# %%
t1
# Out:
# (10, 20, 30, 40, 50)

# %%
t2
# Out:
# (5, 2, 5, 8, 5, 9)

# %%
t1+t2
# Out:
# (10, 20, 30, 40, 50, 5, 2, 5, 8, 5, 9)

# %%
t1*3
# Out:
# (10, 20, 30, 40, 50, 10, 20, 30, 40, 50, 10, 20, 30, 40, 50)

# %%
t1
# Out:
# (10, 20, 30, 40, 50)

# %%
t1[1:4]
# Out:
# (20, 30, 40)

# %%
t1=[10,20,30,40,50]
my_tuple=tuple(t1)
print(my_tuple)
# Out:
# (10, 20, 30, 40, 50)

# %%
print(type(my_tuple))
# Out:
# <class 'tuple'>

# %%
d1=(10,20,30,40,70,80,100)

# %%
max(d1)
# Out:
# 100

# %%
min(d1)
# Out:
# 10

# %%
sum(d1)
# Out:
# 350

# %%
sorted(d1,reverse="True")
# Out:
# [100, 80, 70, 40, 30, 20, 10]

# %% [raw]
# sorted(d1)

# %%
sorted(d1)
# Out:
# [10, 20, 30, 40, 70, 80, 100]

# %%
d2=(50,50,60,70,80,100,60)
my_list=list(d2)
print(my_list)
# Out:
# [50, 50, 60, 70, 80, 100, 60]

# %%
my_list.remove(50)

# %%
my_list
# Out:
# [50, 60, 70, 80, 100, 60]

# %%
my_list.remove(60)

# %%
my_list
# Out:
# [50, 70, 80, 100, 60]

# %%
d2=tuple(my_list)
print(d2)
# Out:
# (50, 70, 80, 100, 60)

# %%
d2
# Out:
# (50, 70, 80, 100, 60)

# %%
my_list=list(d2)
print(my_list)
# Out:
# [50, 70, 80, 100, 60]

# %%
my_list.append(90)

# %%
my_list
# Out:
# [50, 70, 80, 100, 60, 90]

# %%
d2=tuple(my_list)
print(d2)
# Out:
# (50, 70, 80, 100, 60, 90)

# %%
d2
# Out:
# (50, 70, 80, 100, 60, 90)

# %%
temp= list(d2)
temp[0], temp[1] = temp[-1], temp[0]
d2= tuple(temp)
print(d2)
# Out:
# (90, 90, 80, 100, 60, 90)

# %%
d2
# Out:
# (90, 90, 80, 100, 60, 90)

# %%
max > (d2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 max > (d2)
#
# TypeError: '>' not supported between instances of 'builtin_function_or_method' and 'tuple'
