# %%
#Dictionary methods
d1={"name":"Rohit","age":"20","course":"BCA"}

# %%
d1
# Out:
# {'name': 'Rohit', 'age': '20', 'course': 'BCA'}

# %%
d1["name"]
# Out:
# 'Rohit'

# %%
d1["age"]
# Out:
# '20'

# %%
d1
# Out:
# {'name': 'Rohit', 'age': '20', 'course': 'BCA'}

# %%
d1.update({"name":"Amey","age":21,"course":"BCA"})

# %%
d1
# Out:
# {'name': 'Amey', 'age': 21, 'course': 'BCA'}

# %%
d2={"name":"Rohit","age":"20","course":"BCA","name":"Amey","age":"20","course":"BCA"}

# %%
d1
# Out:
# {'name': 'Amey', 'age': '20', 'course': 'BCA'}

# %%
d2
# Out:
# {'name': 'Amey', 'age': '20', 'course': 'BCA'}

# %%
d2.get("name")
# Out:
# 'Amey'

# %%
d2.get('age')
# Out:
# '20'

# %%
d2.keys()
# Out:
# dict_keys(['name', 'age', 'course'])

# %%
d2.values()
# Out:
# dict_values(['Amey', '20', 'BCA'])

# %%
d2.update({"name":"Sahil"})

# %%
d2
# Out:
# {'name': 'Sahil', 'age': '20', 'course': 'BCA'}

# %%
d2.pop("course")
# Out:
# 'BCA'

# %%
d2
# Out:
# {'name': 'Sahil', 'age': '20'}

# %%
d2.popitem()
# Out:
# ('age', '20')

# %%
d2.update({"name":"Deepak","age":22,"course":"BCA"})

# %%
d2
# Out:
# {'name': 'Deepak', 'age': 22, 'course': 'BCA'}

# %%
d2.copy()
# Out:
# {'name': 'Deepak', 'age': 22, 'course': 'BCA'}

# %%
d2.clear()

# %%
#operation
d={"Name":"Deepak","Age":21,"Sub":"English","marks":90}

# %%
d
# Out:
# {'Name': 'Deepak', 'Age': 21, 'Sub': 'English', 'marks': 90}

# %%
d["Name"]
# Out:
# 'Deepak'

# %%
d["marks"]
# Out:
# 90

# %%
d["city"]="Pune"

# %%
d
# Out:
# {'Name': 'Deepak', 'Age': 21, 'Sub': 'English', 'marks': 90, 'city': 'Pune'}

# %%
d["Rollno"]=74

# %%
d
# Out:
# {'Name': 'Deepak',
#  'Age': 21,
#  'Sub': 'English',
#  'marks': 90,
#  'city': 'Pune',
#  'Rollno': 74}

# %%
d.update({"Age":22})

# %%
d
# Out:
# {'Name': 'Deepak',
#  'Age': 22,
#  'Sub': 'English',
#  'marks': 90,
#  'city': 'Pune',
#  'Rollno': 74,
#  'age': 22}

# %%
d.update({"Name":"Amey"})

# %%
d
# Out:
# {'Name': 'Amey',
#  'Age': 22,
#  'Sub': 'English',
#  'marks': 90,
#  'city': 'Pune',
#  'Rollno': 74,
#  'age': 22,
#  'name': 'Amey'}

# %%
del d["age"]

# %%
d
# Out:
# {'Name': 'Amey',
#  'Age': 22,
#  'Sub': 'English',
#  'marks': 90,
#  'city': 'Pune',
#  'Rollno': 74,
#  'name': 'Amey'}

# %%
del d["name"]

# %%
d
# Out:
# {'Name': 'Amey',
#  'Age': 22,
#  'Sub': 'English',
#  'marks': 90,
#  'city': 'Pune',
#  'Rollno': 74}

# %%
"name" in d
# Out:
# False

# %%
"Name" in d
# Out:
# True

# %%
"Rollno" not in d
# Out:
# False

# %%
len(d)
# Out:
# 6

# %%
max(d)
# Out:
# 'marks'

# %%
min(d)
# Out:
# 'Age'
